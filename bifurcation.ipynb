# %%
from bifurcation import Bifurcation

# %%
b2 = Bifurcation(logistic_map_iterations=100, x0=.15, ratios_density=500)
b2.run()
b2.plot(width=4, alpha=.2, s=.5)

# %%
b2 = Bifurcation(logistic_map_iterations=50, ratios_density=5000, skip_first_k=20)
b2.run()
b2.plot(width=20, alpha=.5, s=1)
